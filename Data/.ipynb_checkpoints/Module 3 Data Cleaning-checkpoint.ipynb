# %%
import json
import string
import nltk
import pandas as pd
import numpy as np
import itertools

# %%
business = pd.read_json('business_city.json', lines=True)
review = pd.read_json('review_city.json', lines=True)
tip = pd.read_json('tip_city.json', lines=True)
user = pd.read_json('user_city.json', lines=True)

# %%
Hotel_index = np.where(business.categories.str.contains('Hotel').values)[0]
Hotel_business = business.iloc[Hotel_index,]
Hotel_business.head()
# Out:
#                 business_id                                          name  \
# 73   0JOuIE9U2NJ34Plkrx2k-Q                Wayne Ace Bus And Limo Service
# 83   B_wz5DFPuYBLedrk8XW6jA                           Holiday Inn Express
# 114  RqwuaHAybTqbkmGe1RZLXQ  Embassy Suites by Hilton Cleveland Beachwood
# 127  L2rs-zndfHOgIcqBrxApqw                             PC Travel Service
# 151  ke6AaINpIFkhCiG0q4lprA                                          Uber
#
#                address          city state postal_code   latitude  longitude  \
# 73    1219 County Rd D        Oregon    WI       53575  42.926112 -89.384563
# 83      2850 Medina Rd        Medina    OH       44256  41.135395 -81.790136
# 114  3775 Park East Dr     Beachwood    OH       44122  41.457708 -81.492653
# 127     31 Longview Dr  McKees Rocks    PA       15136  40.460410 -80.099705
# 151                        Cleveland    OH       44101  41.490803 -81.672676
#
#      stars  review_count  is_open  \
# 73     3.0            11        1
# 83     4.0             3        0
# 114    3.0            71        1
# 127    2.5             3        1
# 151    3.0            24        1
#
#                                             attributes  \
# 73                                                None
# 83   {'BusinessAcceptsCreditCards': 'True', 'Restau...
# 114  {'RestaurantsPriceRange2': '2', 'BusinessAccep...
# 127   {'ByAppointmentOnly': 'True', 'WiFi': 'u'free''}
# 151                                               None
#
#                                             categories  \
# 73   Hotels & Travel, Limos, Buses, Airport Shuttle...
# 83   Hotels & Travel, Hotels, Event Planning & Serv...
# 114  Event Planning & Services, Hotels, Hotels & Tr...
# 127                   Travel Services, Hotels & Travel
# 151             Transportation, Taxis, Hotels & Travel
#
#                                                  hours
# 73   {'Monday': '0:0-0:0', 'Tuesday': '0:0-0:0', 'W...
# 83                                                None
# 114  {'Monday': '0:0-0:0', 'Tuesday': '0:0-0:0', 'W...
# 127  {'Monday': '9:30-17:30', 'Tuesday': '9:30-17:3...
# 151                                               None

# %%
Hotel_business.shape
# Out:
# (1257, 14)

# %%
raw_Review_Hotel = pd.merge(review,Hotel_business, how="left",on="business_id")
raw_Review_Hotel.head()
# Out:
#                 review_id                 user_id             business_id  \
# 0  LG2ZaYiOgpr2DK_90pYjNw  V34qejxNsCbcgD8C0HVk-Q  HQl28KMwrEKHqhFrrDqVNQ
# 1  qWHp2l2lysENZObh6MAulA  5lb0POg2t-AkMFx6603cYQ  ZlCSsWS07JulSBIQlrbF5w
# 2  Ne_2CSfcKIqXHmv_KC0uqg  6sJN_HlM_uwpfLJ1puf1Fg  oVuZtlCFg_zF090Nhtp0Ow
# 3  2mLlQ9n5Ln_fykOuX_b0-A  EZ6g9a17UdMjtR-wrZebmA  wSAGILK2CFbq5BVZ5D67-A
# 4  Ymb8ZYPg2e8dvqhdj3Gkqw  hHFSpKcnDtJOs6M-JKFZ8Q  oCvxJBOs-Mbg-4oanPO7lQ
#
#    stars_x  useful  funny  cool  \
# 0        5       1      0     0
# 1        5       1      0     0
# 2        4       3      0     1
# 3        3       0      0     0
# 4        4       0      0     0
#
#                                                 text                date  \
# 0  I love Deagan's. I do. I really do. The atmosp... 2015-12-05 03:18:11
# 1  Called for a 5:15 morning reservation. The dri... 2015-05-26 10:36:47
# 2  A close friend was in town and so instead of t... 2018-02-01 19:15:00
# 3  The service is attentive. The decor attractive... 2015-06-21 00:07:59
# 4  The ingredients are always fresh and I like th... 2016-10-26 14:53:42
#
#                name  ... state postal_code   latitude  longitude  stars_y  \
# 0               NaN  ...   NaN         NaN        NaN        NaN      NaN
# 1  Black Cab & Limo  ...    IL              40.116420 -88.243383      4.5
# 2               NaN  ...   NaN         NaN        NaN        NaN      NaN
# 3             Adega  ...    OH       44115  41.499615 -81.685922      4.0
# 4               NaN  ...   NaN         NaN        NaN        NaN      NaN
#
#    review_count  is_open                                         attributes  \
# 0           NaN      NaN                                                NaN
# 1          28.0      1.0                                {'WiFi': 'u'free''}
# 2           NaN      NaN                                                NaN
# 3         201.0      1.0  {'BusinessAcceptsCreditCards': 'True', 'Restau...
# 4           NaN      NaN                                                NaN
#
#                                           categories  \
# 0                                                NaN
# 1  Airport Shuttles, Transportation, Taxis, Hotel...
# 2                                                NaN
# 3  Mediterranean, Hotels, Beer, Wine & Spirits, B...
# 4                                                NaN
#
#                                                hours
# 0                                                NaN
# 1  {'Monday': '8:0-20:0', 'Tuesday': '8:0-20:0', ...
# 2                                                NaN
# 3  {'Monday': '6:30-22:0', 'Tuesday': '6:30-22:0'...
# 4                                                NaN
#
# [5 rows x 22 columns]

# %%
raw_Review_Hotel.shape
# Out:
# (942027, 22)

# %%
raw_Review_Hotel.columns
# Out:
# Index(['review_id', 'user_id', 'business_id', 'stars_x', 'useful', 'funny',
#        'cool', 'text', 'date', 'name', 'address', 'city', 'state',
#        'postal_code', 'latitude', 'longitude', 'stars_y', 'review_count',
#        'is_open', 'attributes', 'categories', 'hours'],
#       dtype='object')

# %%
Review_Hotel = raw_Review_Hotel.drop(columns=['business_id', 'review_id', 'user_id', 'funny', 'cool', 'date', 'latitude', 'longitude', 'is_open', 'review_count', 'hours'])
Review_Hotel.head()
# Out:
#    stars_x  useful                                               text  \
# 0        5       1  I love Deagan's. I do. I really do. The atmosp...
# 1        5       1  Called for a 5:15 morning reservation. The dri...
# 2        4       3  A close friend was in town and so instead of t...
# 3        3       0  The service is attentive. The decor attractive...
# 4        4       0  The ingredients are always fresh and I like th...
#
#                name        address       city state postal_code  stars_y  \
# 0               NaN            NaN        NaN   NaN         NaN      NaN
# 1  Black Cab & Limo                 Champaign    IL                  4.5
# 2               NaN            NaN        NaN   NaN         NaN      NaN
# 3             Adega  2017 E 9th St  Cleveland    OH       44115      4.0
# 4               NaN            NaN        NaN   NaN         NaN      NaN
#
#                                           attributes  \
# 0                                                NaN
# 1                                {'WiFi': 'u'free''}
# 2                                                NaN
# 3  {'BusinessAcceptsCreditCards': 'True', 'Restau...
# 4                                                NaN
#
#                                           categories
# 0                                                NaN
# 1  Airport Shuttles, Transportation, Taxis, Hotel...
# 2                                                NaN
# 3  Mediterranean, Hotels, Beer, Wine & Spirits, B...
# 4                                                NaN

# %%
Review_Hotel.shape
# Out:
# (942027, 11)

# %%
text = list(Review_Hotel.text)

# %%
len(text)
# Out:
# 942027

# %%
text = [a.lower() for a in text]
text = ["".join([char for char in a if char not in string.punctuation]) for a in text]

# %%
words = [nltk.word_tokenize(a) for a in text]
# Out:
# ['i',
#  'love',
#  'deagans',
#  'i',
#  'do',
#  'i',
#  'really',
#  'do',
#  'the',
#  'atmosphere',
#  'is',
#  'cozy',
#  'and',
#  'festive',
#  'the',
#  'shrimp',
#  'tacos',
#  'and',
#  'house',
#  'fries',
#  'are',
#  'my',
#  'standbys',
#  'the',
#  'fries',
#  'are',
#  'sometimes',
#  'good',
#  'and',
#  'sometimes',
#  'great',
#  'and',
#  'the',
#  'spicy',
#  'dipping',
#  'sauce',
#  'they',
#  'come',
#  'with',
#  'is',
#  'to',
#  'die',
#  'for',
#  'the',
#  'beer',
#  'list',
#  'is',
#  'amazing',
#  'and',
#  'the',
#  'cocktails',
#  'are',
#  'great',
#  'the',
#  'prices',
#  'are',
#  'midlevel',
#  'so',
#  'its',
#  'not',
#  'a',
#  'cheap',
#  'dive',
#  'you',
#  'can',
#  'go',
#  'to',
#  'every',
#  'week',
#  'but',
#  'rather',
#  'a',
#  'treat',
#  'when',
#  'you',
#  'do',
#  'try',
#  'it',
#  'out',
#  'you',
#  'wont',
#  'be',
#  'disappointed']

# %%
from nltk.corpus import stopwords
stop_words = stopwords.words('english')
filtered_words = [[word for word in a if word not in stop_words] for a in words]
# Out:
# ['love',
#  'deagans',
#  'really',
#  'atmosphere',
#  'cozy',
#  'festive',
#  'shrimp',
#  'tacos',
#  'house',
#  'fries',
#  'standbys',
#  'fries',
#  'sometimes',
#  'good',
#  'sometimes',
#  'great',
#  'spicy',
#  'dipping',
#  'sauce',
#  'come',
#  'die',
#  'beer',
#  'list',
#  'amazing',
#  'cocktails',
#  'great',
#  'prices',
#  'midlevel',
#  'cheap',
#  'dive',
#  'go',
#  'every',
#  'week',
#  'rather',
#  'treat',
#  'try',
#  'wont',
#  'disappointed']

# %%
from nltk.stem import WordNetLemmatizer
lmtzr = WordNetLemmatizer()

# %%
lemmatized_words = [[lmtzr.lemmatize(x) for x in a] for a in filtered_words]

# %%
word_list = list(itertools.chain.from_iterable(lemmatized_words))
from collections import Counter
freq = pd.DataFrame.from_dict(Counter(word_list), orient='index')

# %%
freq.sort_values(by=0, ascending=False)
# Out:
#                   0
# food         538349
# place        502567
# good         492422
# great        415604
# time         390748
# ...             ...
# hoursreally       1
# cuscous           1
# tapas2            1
# clud              1
# sealcoater        1
#
# [414105 rows x 1 columns]

# %%
dictionary = list(freq[freq[0] > 10].index)

# %%
word_embedding = np.zeros([len(lemmatized_words), len(dictionary~)])
# Out:
# ---------------------------------------------------------------------------
# MemoryError                               Traceback (most recent call last)
# <ipython-input-48-be1adfd9a496> in <module>
# ----> 1 word_embedding = np.zeros([len(lemmatized_words), len(dictionary)])
#
# MemoryError:

# %%
for i,x in enumerate(lemmatized_words):
    for j,y in enumerate(dictionary):
        word_embedding[i,j] = sum([z == y for z in x])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-49-a3ea04a73f1b> in <module>
#       1 for i,x in enumerate(lemmatized_words):
#       2     for j,y in enumerate(dictionary):
# ----> 3         word_embedding[i,j] = sum([z == y for z in x])
#
# NameError: name 'word_embedding' is not defined

# %%
burgers_tip.to_csv('burgers_tip.csv')
